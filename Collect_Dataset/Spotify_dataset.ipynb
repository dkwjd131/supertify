# %% [markdown]
# <a href="https://colab.research.google.com/github/JeongYoon-L/supertify/blob/JeongYoon/Spotify_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Set up

# %%
# !pip install spotipy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 62 kB 1.3 MB/s
# ...
#      |████████████████████████████████| 246 kB 11.1 MB/s
# ...
#      |████████████████████████████████| 138 kB 55.4 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.28.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
client_credentials_manager = SpotifyClientCredentials(client_id='d9970216ab7545ba95719e17a67644b5', client_secret='1201d4f005a047a2a0eedef2df6e2eba')
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# #Get1000 tracks for each year (5 years)

# %% [markdown]
# ##2021 released tracks (1000)

# %%
artist_name =[]
track_name = []
track_popularity =[]
artist_id =[]
track_id =[]
album_id = []
release_date = []
release_date_precision = []
duration_ms = []
artist_genre = []
artist_popularity = []

for i in range(0,1000,50):
    track_results_2021 = sp.search(q='year:2021', type='track', limit=50, offset=i)
    for i, t in enumerate(track_results_2021['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        artist_id.append(t['artists'][0]['id'])
        art = sp.artist(t['artists'][0]['id'])
        artist_genre.append(art['genres'])
        artist_popularity.append(art['popularity'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        album_id.append(t['album']['id'])
        duration_ms.append(t['duration_ms'])
        track_popularity.append(t['popularity'])
        release_date.append(t['album']['release_date'])
        release_date_precision.append(t['album']['release_date_precision'])

# %%
import pandas as pd
track_df_2021 = pd.DataFrame({'artist_name' : artist_name, 'track_name' : track_name, 'track_id' : track_id, 'album_id' : album_id, 'artist_id' : artist_id ,'track_popularity' : track_popularity,'artist_popularity':artist_popularity, 'artist_genre': artist_genre, 'duration_ms' : duration_ms , 'release_date': release_date, 'release_date_precision' : release_date_precision})
print(track_df_2021.shape)
track_df_2021
# Out:
# (1000, 11)
#                           artist_name  \
# 0                            Doja Cat
# 1                          Otmar Eros
# 2                       Morgan Wallen
# 3    Elvis Costello & The Attractions
# 4                      Olivia Rodrigo
# ..                                ...
# 995                    Above & Beyond
# 996                           BRELAND
# 997                       Paul Thomas
# 998                               che
# 999                    Above & Beyond
#
#                                            track_name                track_id  \
# 0                                               Woman  6Uj1ctrBOjOas8xZXGqKk4
# 1                                   Year 2016:, Pt. 4  1sUxW2zAmXA7lXHC8Dxu4s
# 2                                       Wasted On You  3cBsEDNhFI9E82vPj3kvi3
# 3                          Pump It Up - 2021 Remaster  3oyc1mIdCBGaU55wX7otqM
# 4                                            good 4 u  4ZtFanR9U6ndgddUvNcjcG
# ...

# %% [markdown]
# ###audio_features 2021

# %%
track_features = []
for t_id in track_df_2021['track_id']:
    af = sp.audio_features(t_id)
    track_features.append(af)
tf_df_2021 = pd.DataFrame(columns = ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms', 'time_signature'])
for item in track_features:
    for feat in item:
        tf_df_2021 = tf_df_2021.append(feat, ignore_index=True)
tf_df_2021.head()
# Out:
#    danceability  energy key  loudness mode  speechiness  acousticness  \
# 0         0.824   0.764   5    -4.175    0       0.0854      0.088800
# 1         0.608   0.841   9    -8.354    1       0.0293      0.000672
# 2         0.505   0.657  11    -5.240    0       0.0318      0.373000
# 3         0.645   0.809  11    -6.120    1       0.0385      0.009210
# 4         0.563   0.664   9    -5.044    1       0.1540      0.335000
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.002940    0.1170    0.881  107.998  audio_features
# 1          0.000017    0.0704    0.185  129.994  audio_features
# 2          0.001070    0.1260    0.252  196.000  audio_features
# 3          0.001080    0.1060    0.966  138.978  audio_features
# 4          0.000000    0.0849    0.688  166.928  audio_features
#
#                        id                                   uri  \
# 0  6Uj1ctrBOjOas8xZXGqKk4  spotify:track:6Uj1ctrBOjOas8xZXGqKk4
# ...

# %% [markdown]
# ###audio_analysis 2021

# %%
track_analysis = []
for t_id in track_df_2021['track_id']:
    af = sp.audio_analysis(t_id)
    track_analysis.append(af)
tf_df_2021_analysis = pd.DataFrame(columns = ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'type', 'id', 'url', 'track_href', 'analysis_url', 'duration_ms', 'time_signature'])
for item in track_analysis:
    for feat in item:
        tf_df_2021_analysis = tf_df_2021_analysis.append(feat, ignore_index=True)
tf_df_2021_analysis.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-d7c1a7a41ab8> in <module>()
#       1 track_analysis = []
#       2 for t_id in track_df_2021['track_id']:
# ----> 3     af = sp.audio_analysis(t_id)
#       4     track_analysis.append(af)
#       5 tf_df_2021_analysis = pd.DataFrame(columns = ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'type', 'id', 'url', 'track_href', 'analysis_url', 'duration_ms', 'time_signature'])
#
# /usr/local/lib/python3.7/dist-packages/spotipy/client.py in audio_analysis(self, track_id)
#    1669         """
#    1670         trid = self._get_id("track", track_id)
# -> 1671         return self._get("audio-analysis/" + trid)
#    1672
#    1673     def audio_features(self, tracks=[]):
#
# ...

# %% [markdown]
# Some of songs are not released on 2021, this is because they are remaster album

# %% [markdown]
# ##2020 released tracks (1000)

# %%
artist_name =[]
track_name = []
track_popularity =[]
artist_id =[]
track_id =[]
album_id = []
release_date = []
release_date_precision = []
duration_ms = []
artist_genre = []
artist_popularity = []

for i in range(0,1000,50):
    track_results_2020 = sp.search(q='year:2020', type='track', limit=50, offset=i)
    for i, t in enumerate(track_results_2020['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        artist_id.append(t['artists'][0]['id'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        art = sp.artist(t['artists'][0]['id'])
        artist_genre.append(art['genres'])
        artist_popularity.append(art['popularity'])
        album_id.append(t['album']['id'])
        duration_ms.append(t['duration_ms'])
        track_popularity.append(t['popularity'])
        release_date.append(t['album']['release_date'])
        release_date_precision.append(t['album']['release_date_precision'])

# %%
import pandas as pd
track_df_2020 = pd.DataFrame({'artist_name' : artist_name, 'track_name' : track_name, 'track_id' : track_id, 'album_id' : album_id, 'artist_id' : artist_id ,'track_popularity' : track_popularity, 'artist_popularity': artist_popularity, 'artist_genre': artist_genre, 'duration_ms' : duration_ms , 'release_date': release_date, 'release_date_precision' : release_date_precision})
print(track_df_2020.shape)
track_df_2020
# Out:
# (1000, 11)
#         artist_name                track_name                track_id  \
# 0        Elley Duhé       MIDDLE OF THE NIGHT  58HvfVOeJY7lUuCqF0m3ly
# 1           Hammock       Longest Year (2020)  0MlkZnfwsjwHHSfn07N8ao
# 2     Glass Animals                Heat Waves  3USxtqRwSYz57Ewm6wWRMp
# 3       Tame Impala      Alter Ego - 2020 Mix  457sndKohlwTU6dW6amBMU
# 4        The Weeknd           Blinding Lights  0VjIjW4GlUZAMYd2vXMi3b
# ..              ...                       ...                     ...
# 995  Workout Music   Beautiful People (Remix)  3O1lskEk6MF8bEQ76Q7Cmv
# 996            Lauv           Who (feat. BTS)  2qG81jL9UIP54uS8gYyP4k
# 997  Workout Music      Old Town Road (Remix)  2YYO2IuGe6dI9Lv3mpeUWo
# 998    Punkinloveee                Freak Show  2Rb6nYmuLEblpq4KIAjngL
# 999   Jacob Lizotte                   Epitaph  0eC7nOJsIUUfuOUiDk7aVa
#
#                    album_id               artist_id  track_popularity  \
# ...

# %% [markdown]
# ###audio features 2020

# %%
track_features = []
for t_id in track_df_2020['track_id']:
    af = sp.audio_features(t_id)
    track_features.append(af)
tf_df_2020 = pd.DataFrame(columns = ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms', 'time_signature'])
for item in track_features:
    for feat in item:
        tf_df_2020 = tf_df_2020.append(feat, ignore_index=True)
tf_df_2020.head()
# Out:
#    danceability  energy key  loudness mode  speechiness  acousticness  \
# 0        0.4100   0.611   4    -8.271    0       0.0467       0.02280
# 1        0.0705   0.286   2   -14.865    1       0.0444       0.68500
# 2        0.7610   0.525  11    -6.900    1       0.0944       0.44000
# 3        0.4080   0.903   0    -2.924    1       0.0561       0.00256
# 4        0.5140   0.730   1    -5.934    1       0.0598       0.00146
#
#   instrumentalness  liveness  valence    tempo            type  \
# 0                0    0.1160   0.0899  185.727  audio_features
# 1            0.675    0.1870   0.0313   78.251  audio_features
# 2         0.000007    0.0921   0.5310   80.870  audio_features
# 3         0.000821    0.1170   0.3680  128.942  audio_features
# 4         0.000095    0.0897   0.3340  171.005  audio_features
#
#                        id                                   uri  \
# 0  58HvfVOeJY7lUuCqF0m3ly  spotify:track:58HvfVOeJY7lUuCqF0m3ly
# ...

# %% [markdown]
# ##2019 released tracks(1000)

# %%
artist_name =[]
track_name = []
track_popularity =[]
artist_id =[]
track_id =[]
album_id = []
release_date = []
release_date_precision = []
duration_ms = []
artist_genre = []
artist_popularity = []

for i in range(0,1000,50):
    track_results_2019 = sp.search(q='year:2019', type='track', limit=50, offset=i)
    for i, t in enumerate(track_results_2019['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        artist_id.append(t['artists'][0]['id'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        art = sp.artist(t['artists'][0]['id'])
        artist_genre.append(art['genres'])
        artist_popularity.append(art['popularity'])
        album_id.append(t['album']['id'])
        duration_ms.append(t['duration_ms'])
        track_popularity.append(t['popularity'])
        release_date.append(t['album']['release_date'])
        release_date_precision.append(t['album']['release_date_precision'])

# %%
import pandas as pd
track_df_2019 = pd.DataFrame({'artist_name' : artist_name, 'track_name' : track_name, 'track_id' : track_id, 'album_id' : album_id, 'artist_id' : artist_id ,'track_popularity' : track_popularity,'artist_popularity':artist_popularity, 'artist_genre': artist_genre, 'duration_ms' : duration_ms , 'release_date': release_date, 'release_date_precision' : release_date_precision})
print(track_df_2019.shape)
track_df_2019
# Out:
# (1000, 11)
#            artist_name                         track_name  \
# 0         Harry Styles                   Watermelon Sugar
# 1           Otmar Eros                  Year 2016:, Pt. 4
# 2          Post Malone                            Circles
# 3        Calvin Harris                           One Kiss
# 4             Yot Club                             YKWIM?
# ..                 ...                                ...
# 995        Xavier Wulf                   Kid Cudi - Remix
# 996   DJ Chill del Mar                             # 2019
# 997  Sabrina Carpenter                      Looking at Me
# 998          Eric Senn                        Coelum 2019
# 999           Lil Tjay  Brothers (feat. Lil Durk) - Remix
#
#                    track_id                album_id               artist_id  \
# 0    6UelLqGlWMcVH1E5c4H7lY  7xV2TzoaVc0ycW7fwBwAml  6KImCVD70vtIoJWnq6nGn3
# 1    1sUxW2zAmXA7lXHC8Dxu4s  21AA25PUsBnGgzLmiCFhX6  5XY9JN9PcQ41KQTZqtyhsL
# ...

# %% [markdown]
# ###audio_features 2019

# %%
track_features = []
for t_id in track_df_2019['track_id']:
    af = sp.audio_features(t_id)
    track_features.append(af)
tf_df_2019 = pd.DataFrame(columns = ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms', 'time_signature'])
for item in track_features:
    for feat in item:
        tf_df_2019 = tf_df_2019.append(feat, ignore_index=True)
tf_df_2019.head()
# Out:
#    danceability  energy key  loudness mode  speechiness  acousticness  \
# 0         0.548   0.816   0    -4.209    1       0.0465        0.1220
# 1         0.241   0.064   5   -24.272    1       0.0602        0.9940
# 2         0.695   0.762   0    -3.497    1       0.0395        0.1920
# 3         0.753   0.852   9    -4.028    0       0.1380        0.0319
# 4         0.372   0.537   9    -7.623    1       0.0305        0.9370
#
#   instrumentalness  liveness  valence    tempo            type  \
# 0                0    0.3350   0.5570   95.390  audio_features
# 1             0.95    0.0715   0.0372  141.739  audio_features
# 2          0.00244    0.0863   0.5530  120.042  audio_features
# 3         0.000009    0.3280   0.5860  124.023  audio_features
# 4            0.873    0.2870   0.2280  123.735  audio_features
#
#                        id                                   uri  \
# 0  6UelLqGlWMcVH1E5c4H7lY  spotify:track:6UelLqGlWMcVH1E5c4H7lY
# ...

# %% [markdown]
# ##2018 released tracks (1000)

# %%
artist_name =[]
track_name = []
track_popularity =[]
artist_id =[]
track_id =[]
album_id = []
release_date = []
release_date_precision = []
duration_ms = []
artist_genre = []
artist_popularity = []

for i in range(0,1000,50):
    track_results_2018 = sp.search(q='year:2018', type='track', limit=50, offset=i)
    for i, t in enumerate(track_results_2018['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        artist_id.append(t['artists'][0]['id'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        art = sp.artist(t['artists'][0]['id'])
        artist_genre.append(art['genres'])
        artist_popularity.append(art['popularity'])
        album_id.append(t['album']['id'])
        duration_ms.append(t['duration_ms'])
        track_popularity.append(t['popularity'])
        release_date.append(t['album']['release_date'])
        release_date_precision.append(t['album']['release_date_precision'])

# %%
import pandas as pd
track_df_2018 = pd.DataFrame({'artist_name' : artist_name, 'track_name' : track_name, 'track_id' : track_id, 'album_id' : album_id, 'artist_id' : artist_id ,'track_popularity' : track_popularity,'artist_popularity':artist_popularity, 'artist_genre': artist_genre, 'duration_ms' : duration_ms , 'release_date': release_date, 'release_date_precision' : release_date_precision})
print(track_df_2018.shape)
track_df_2018
# Out:
# (1000, 11)
#                     artist_name                                    track_name  \
# 0                 Morgan Wallen                               Whiskey Glasses
# 1                    Otmar Eros                             Year 2016:, Pt. 4
# 2                          Joji                      SLOW DANCING IN THE DARK
# 3                 Fleetwood Mac  Rhiannon (Will You Ever Win) - 2018 Remaster
# 4                    Juice WRLD                                  Lucid Dreams
# ..                          ...                                           ...
# 995           Jonathan Reichert                Ten Years Reminder (2008-2018)
# 996  YoungBoy Never Broke Again                                         Genie
# 997               Aakash Mishra                Happy New Year 2018 - Bhojpuri
# 998                    Maroon 5                                Girls Like You
# 999              Alwarsha Beatz                   Happy Fucking New Year 2018
#
# ...

# %% [markdown]
# ###Audio_features 2018

# %%
track_features = []
for t_id in track_df_2018['track_id']:
    af = sp.audio_features(t_id)
    track_features.append(af)
tf_df_2018 = pd.DataFrame(columns = ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms', 'time_signature'])
for item in track_features:
    for feat in item:
        tf_df_2018 = tf_df_2018.append(feat, ignore_index=True)
tf_df_2018.head()
# Out:
#    danceability  energy key  loudness mode  speechiness  acousticness  \
# 0         0.614   0.680   6    -4.580    1       0.0289         0.369
# 1         0.241   0.064   5   -24.272    1       0.0602         0.994
# 2         0.515   0.479   3    -7.458    1       0.0261         0.544
# 3         0.684   0.638   9    -9.025    0       0.0312         0.365
# 4         0.511   0.566   6    -7.230    0       0.2000         0.349
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000002    0.1150   0.7070  149.959  audio_features
# 1          0.950000    0.0715   0.0372  141.739  audio_features
# 2          0.005980    0.1910   0.2840   88.964  audio_features
# 3          0.020700    0.1190   0.8100  129.959  audio_features
# 4          0.000000    0.3400   0.2180   83.903  audio_features
#
#                        id                                   uri  \
# 0  6foY66mWZN0pSRjZ408c00  spotify:track:6foY66mWZN0pSRjZ408c00
# ...

# %% [markdown]
# ## 2017 released tracks (1000)

# %%
artist_name =[]
track_name = []
track_popularity =[]
artist_id =[]
track_id =[]
album_id = []
release_date = []
release_date_precision = []
duration_ms = []
artist_genre = []
artist_popularity = []

for i in range(0,1000,50):
    track_results_2017 = sp.search(q='year:2017', type='track', limit=50, offset=i)
    for i, t in enumerate(track_results_2017['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        artist_id.append(t['artists'][0]['id'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        art = sp.artist(t['artists'][0]['id'])
        artist_genre.append(art['genres'])
        artist_popularity.append(art['popularity'])
        album_id.append(t['album']['id'])
        duration_ms.append(t['duration_ms'])
        track_popularity.append(t['popularity'])
        release_date.append(t['album']['release_date'])
        release_date_precision.append(t['album']['release_date_precision'])

# %%
import pandas as pd
track_df_2017 = pd.DataFrame({'artist_name' : artist_name, 'track_name' : track_name, 'track_id' : track_id, 'album_id' : album_id, 'artist_id' : artist_id ,'track_popularity' : track_popularity,'artist_popularity':artist_popularity, 'artist_genre': artist_genre, 'duration_ms' : duration_ms , 'release_date': release_date, 'release_date_precision' : release_date_precision})
print(track_df_2017.shape)
track_df_2017
# Out:
# (1000, 11)
#             artist_name                            track_name  \
# 0            Steve Lacy                              Dark Red
# 1            Otmar Eros                     Year 2016:, Pt. 4
# 2    Tyler, The Creator      See You Again (feat. Kali Uchis)
# 3           Mark Ronson                           Uptown Funk
# 4          Lil Uzi Vert                                20 Min
# ..                  ...                                   ...
# 995    Vikings in Tibet  Silver Years (Pelican Sessions 2017)
# 996     Hillsong UNITED             So Will I (100 Billion X)
# 997     Ten Years After      Year 3,000 Blues - 2017 Remaster
# 998            Big Sean                   Jump Out The Window
# 999              Dinobi                 Last of the Year 2017
#
#                    track_id                album_id               artist_id  \
# 0    37y7iDayfwm3WXn5BiAoRk  5fvUFzgVEni3L7769OabqQ  57vWImR43h4CaDao012Ofp
# ...

# %% [markdown]
# ###audio_features 2017

# %%
track_features = []
for t_id in track_df_2017['track_id']:
    af = sp.audio_features(t_id)
    track_features.append(af)
tf_df_2017 = pd.DataFrame(columns = ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms', 'time_signature'])
for item in track_features:
    for feat in item:
        tf_df_2017 = tf_df_2017.append(feat, ignore_index=True)
tf_df_2017.head()
# Out:
#    danceability  energy key  loudness mode  speechiness  acousticness  \
# 0         0.603   0.783   6    -4.023    1       0.0620       0.44900
# 1         0.241   0.064   5   -24.272    1       0.0602       0.99400
# 2         0.558   0.559   6    -9.222    1       0.0959       0.37100
# 3         0.856   0.609   0    -7.223    1       0.0824       0.00801
# 4         0.773   0.750   8    -4.009    0       0.1170       0.10900
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000008    0.1190   0.7750  172.041  audio_features
# 1          0.950000    0.0715   0.0372  141.739  audio_features
# 2          0.000007    0.1090   0.6200   78.558  audio_features
# 3          0.000082    0.0344   0.9280  114.988  audio_features
# 4          0.000000    0.1740   0.7830  123.426  audio_features
#
#                        id                                   uri  \
# 0  37y7iDayfwm3WXn5BiAoRk  spotify:track:37y7iDayfwm3WXn5BiAoRk
# ...

# %% [markdown]
# ##Export Dataset

# %%
track_df_2021.to_csv("track_df_2021.csv", index = False)
track_df_2020.to_csv("track_df_2020.csv", index = False)
track_df_2019.to_csv("track_df_2019.csv", index = False)
track_df_2018.to_csv("track_df_2018.csv", index = False)
track_df_2017.to_csv("track_df_2017.csv", index = False)

tf_df_2021.to_csv("audio_features_2021.csv", index = False)
tf_df_2020.to_csv("audio_features_2020.csv", index = False)
tf_df_2019.to_csv("audio_features_2019.csv", index = False)
tf_df_2018.to_csv("audio_features_2018.csv", index = False)
tf_df_2017.to_csv("audio_features_2017.csv", index = False)

# %% [markdown]
# ##Append Dataset

# %%
final_audio_feature = tf_df_2021
final_audio_feature.append(tf_df_2020)
final_audio_feature.append(tf_df_2019)
final_audio_feature.append(tf_df_2018)
final_audio_feature.append(tf_df_2017)

print(final_audio_feature)
print(final_audio_feature.shape)
# Out:
#      danceability  energy key  loudness mode  speechiness  acousticness  \
# 0           0.824   0.764   5    -4.175    0       0.0854      0.088800
# 1           0.608   0.841   9    -8.354    1       0.0293      0.000672
# 2           0.505   0.657  11    -5.240    0       0.0318      0.373000
# 3           0.645   0.809  11    -6.120    1       0.0385      0.009210
# 4           0.563   0.664   9    -5.044    1       0.1540      0.335000
# ..            ...     ...  ..       ...  ...          ...           ...
# 995         0.681   0.954   3    -4.471    0       0.0559      0.000155
# 996         0.790   0.730   0    -4.980    1       0.0926      0.058600
# 997         0.550   0.890   9    -6.618    0       0.0264      0.000215
# 998         0.547   0.453   3    -8.779    1       0.0358      0.189000
# 999         0.569   0.758   8    -9.763    1       0.0370      0.009870
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %%
final_track_data = track_df_2021
final_track_data = final_track_data.append(track_df_2020)
final_track_data = final_track_data.append(track_df_2019)
final_track_data = final_track_data.append(track_df_2018)
final_track_data= final_track_data.append(track_df_2017)

print(final_track_data)
print(final_track_data.shape)

#should chcek whether this is working or not
# Out:
#                           artist_name  \
# 0                            Doja Cat
# 1                          Otmar Eros
# 2                       Morgan Wallen
# 3    Elvis Costello & The Attractions
# 4                      Olivia Rodrigo
# ..                                ...
# 995                    Above & Beyond
# 996                           BRELAND
# 997                       Paul Thomas
# 998                               che
# 999                    Above & Beyond
#
#                                            track_name                track_id  \
# 0                                               Woman  6Uj1ctrBOjOas8xZXGqKk4
# 1                                   Year 2016:, Pt. 4  1sUxW2zAmXA7lXHC8Dxu4s
# 2                                       Wasted On You  3cBsEDNhFI9E82vPj3kvi3
# 3                          Pump It Up - 2021 Remaster  3oyc1mIdCBGaU55wX7otqM
# 4                                            good 4 u  4ZtFanR9U6ndgddUvNcjcG
# ...

# %%
final_audio_feature.to_csv("final_audio_feature.csv", index = False,)
final_track_data.to_csv("final_track_data.csv", index = False,encoding="utf-8-sig")
#ascii

# %%
artist_name =[]
track_name = []
track_popularity =[]
artist_id =[]
track_id =[]
album_id = []
release_date = []
release_date_precision = []
duration_ms = []
artist_genre = []
artist_popularity = []

for i in range(0,50,50):
    track_results_2021 = sp.search(q='year:2021', type='track', limit=50, offset=i)
    for i, t in enumerate(track_results_2021['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        artist_id.append(t['artists'][0]['id'])
        art = sp.artist(t['artists'][0]['id'])
        artist_genre.append(art['genres'])
        artist_popularity.append(art['popularity'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        album_id.append(t['album']['id'])
        duration_ms.append(t['duration_ms'])
        track_popularity.append(t['popularity'])
        release_date.append(t['album']['release_date'])
        release_date_precision.append(t['album']['release_date_precision'])

# %%
import pandas as pd
track_df_2021 = pd.DataFrame({'artist_name' : artist_name, 'track_name' : track_name, 'track_id' : track_id, 'album_id' : album_id, 'artist_id' : artist_id ,'track_popularity' : track_popularity,'artist_popularity':artist_popularity, 'artist_genre': artist_genre, 'duration_ms' : duration_ms , 'release_date': release_date, 'release_date_precision' : release_date_precision})
print(track_df_2021.shape)
track_df_2021
# Out:
# (50, 11)
#                          artist_name  \
# 0                           Doja Cat
# 1                         Otmar Eros
# 2                      Morgan Wallen
# 3   Elvis Costello & The Attractions
# 4                     Olivia Rodrigo
# 5                           Jay Sean
# 6                        Nicky Youre
# 7                           Mr.Kitty
# 8                              Drake
# 9   Elvis Costello & The Attractions
# 10                   Stephen Sanchez
# 11                      Hop hip show
# 12                         Lil Nas X
# 13                        Otmar Eros
# 14                    Olivia Rodrigo
# 15  Elvis Costello & The Attractions
# 16                             Drake
# 17                          yt music
# 18                          Doja Cat
# 19                        Otmar Eros
# 20                     The Kid LAROI
# 21                 Lofi Fruits Music
# 22                    Olivia Rodrigo
# 23                              Duck
# ...

# %%
track_df_2021.to_csv("test.csv", index = False,)
track_df_2021.to_csv("test.csv", index = False,encoding="utf-8-sig")
#ascii

# %% [markdown]
# #Replace Korean Letter

# %%
import pandas as pd
final_track_data_final = pd.read_csv('final_track_data.csv')

# %%
print(final_track_data_final)
# Out:
#              artist_name                                        track_name  \
# 0             Steve Lacy                                          Dark Red
# 1             Otmar Eros                                 Year 2016:, Pt. 4
# 2     Tyler, The Creator                  See You Again (feat. Kali Uchis)
# 3            Mark Ronson                                       Uptown Funk
# 4           Lil Uzi Vert                                            20 Min
# ...                  ...                                               ...
# 4964      Above & Beyond  Thing Called Love - Oliver Heldens Remix (Mixed)
# 4965             BRELAND                 Throw It Back (feat. Keith Urban)
# 4966         Paul Thomas                                  Carcerem - Mixed
# 4967                 che                                            agenda
# 4968      Above & Beyond                               Almost Home - Mixed
#
# ...

# %%
dfresult = final_track_data_final[~final_track_data_final['artist_name'].str.contains(r'[ㄱ-ㅣ가-힣]+', na=False, case=False)]
dfresult = final_track_data_final[~final_track_data_final['track_name'].str.contains(r'[ㄱ-ㅣ가-힣]+', na=False, case=False)]

# %%
print(dfresult)
# Out:
#              artist_name                                        track_name  \
# 0             Steve Lacy                                          Dark Red
# 1             Otmar Eros                                 Year 2016:, Pt. 4
# 2     Tyler, The Creator                  See You Again (feat. Kali Uchis)
# 3            Mark Ronson                                       Uptown Funk
# 4           Lil Uzi Vert                                            20 Min
# ...                  ...                                               ...
# 4964      Above & Beyond  Thing Called Love - Oliver Heldens Remix (Mixed)
# 4965             BRELAND                 Throw It Back (feat. Keith Urban)
# 4966         Paul Thomas                                  Carcerem - Mixed
# 4967                 che                                            agenda
# 4968      Above & Beyond                               Almost Home - Mixed
#
# ...

# %%
dfresult.to_csv("final_data_vr2.csv", index = False,)
# dfresult.to_csv("test.csv", index = False,encoding="utf-8-sig")

# %% [markdown]
# ##Recommendation

# %%
# rec_track = []
# rec_track.append('Yellow')
# rec_track.append('In My Place')
# rec_track.append('Clocks')
# rec_track.append('Everglow')
# a = sp.recommendations(seed_tracks = rec_track)
# print(a)

track_results = sp.search(q='Yellow', type='track')
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Yellow&type=track&offset=0&limit=10', 'items': [{'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'}, 'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU', 'id': '4gzpq5DPGxSnKTe4SA8HAU', 'name': 'Coldplay', 'type': 'artist', 'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'}], 'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BY', 'BZ', 'CA', 'CD', 'CG', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IQ', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KG', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'KZ', 'LA
# ...
